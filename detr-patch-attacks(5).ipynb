# %% [markdown]
# # End to End Object Detection with Transformers in ART

# %% [markdown]
# Demo for applying the DEtection TRansformer (DETR) estimator in ART for object detection and attacking the Detection Transformer using the Robust DPatch method.

# %% [markdown]
# ### Define imports, constants and helper functions

# %%
import sys 
# !{sys.executable} -m pip install --user adversarial-robustness-toolbox
# !{sys.executable} -m pip install --user torch
# !{sys.executable} -m pip install --user pillow
# !{sys.executable} -m pip install --user fiftyone



from art.estimators.object_detection.pytorch_detection_transformer import PyTorchDetectionTransformer
from art.attacks.evasion.adversarial_patch.adversarial_patch_pytorch import AdversarialPatchPyTorch
from torchvision.transforms import transforms
import PIL.Image
import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt
import requests
import pandas as pd

from sklearn.metrics import accuracy_score

COCO_CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

def extract_predictions(predictions_, conf_thresh):
    predictions_class = [COCO_CLASSES[i] for i in list(predictions_["labels"])]
    if len(predictions_class) < 1:
        return [], [], []
        
    predictions_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(predictions_["boxes"])]
    predictions_score = list(predictions_["scores"])

    threshold = conf_thresh
    predictions_t = [predictions_score.index(x) for x in predictions_score if x > threshold]
    if len(predictions_t) > 0:
        predictions_t = predictions_t
    else:
        return [], [], []
        
    predictions_boxes = [predictions_boxes[i] for i in predictions_t]
    predictions_class = [predictions_class[i] for i in predictions_t]
    predictions_scores = [predictions_score[i] for i in predictions_t]
    return predictions_class, predictions_boxes, predictions_scores

def plot_image_with_boxes(img, boxes, pred_cls, title):
    text_size = 2
    text_th = 2
    rect_th = 2

    for i in range(len(boxes)):
        cv2.rectangle(img, (int(boxes[i][0][0]), int(boxes[i][0][1])), (int(boxes[i][1][0]), int(boxes[i][1][1])),
                      color=(0, 255, 0), thickness=rect_th)
        cv2.putText(img, pred_cls[i], (int(boxes[i][0][0]), int(boxes[i][0][1])), cv2.FONT_HERSHEY_SIMPLEX, text_size,
                    (0, 255, 0), thickness=text_th)
    plt.figure()
    plt.axis("off")
    plt.title(title)
    plt.imshow(img)

def filter_boxes(predictions, conf_thresh):
    dictionary = {}

    boxes_list = []
    scores_list = []
    labels_list = []

    for i in range(len(predictions[0]["boxes"])):
        score = predictions[0]["scores"][i]
        if score >= conf_thresh:
            boxes_list.append(predictions[0]["boxes"][i])
            scores_list.append(predictions[0]["scores"][[i]])
            labels_list.append(predictions[0]["labels"][[i]])

    dictionary["boxes"] = np.vstack(boxes_list)
    dictionary["scores"] = np.hstack(scores_list)
    dictionary["labels"] = np.hstack(labels_list)

    y = [dictionary]

    return y

MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
NUMBER_CHANNELS = 3
INPUT_SHAPE = (NUMBER_CHANNELS, 800, 800)

transform = transforms.Compose([
        transforms.Resize([INPUT_SHAPE[1], INPUT_SHAPE[2]], interpolation=transforms.InterpolationMode.BICUBIC),
        transforms.ToTensor()
    ])
# Out:
# Requirement already satisfied: adversarial-robustness-toolbox in ./lib/python3.10/site-packages (1.15.2)
# Requirement already satisfied: tqdm in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from adversarial-robustness-toolbox) (4.64.1)
# Requirement already satisfied: scipy>=1.4.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from adversarial-robustness-toolbox) (1.9.1)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from adversarial-robustness-toolbox) (63.2.0)
# Requirement already satisfied: six in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from adversarial-robustness-toolbox) (1.16.0)
# Requirement already satisfied: scikit-learn<1.2.0,>=0.22.2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from adversarial-robustness-toolbox) (1.1.2)
# Requirement already satisfied: numpy>=1.18.0 in ./lib/python3.10/site-packages (from adversarial-robustness-toolbox) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (1.1.0)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Requirement already satisfied: torch in ./lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: networkx in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from torch) (2.8.6)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: typing-extensions in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from torch) (4.3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: filelock in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from torch) (3.8.0)
# Requirement already satisfied: jinja2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: triton==2.0.0 in ./lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: sympy in ./lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (63.2.0)
# Requirement already satisfied: wheel in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: lit in ./lib/python3.10/site-packages (from triton==2.0.0->torch) (17.0.1)
# Requirement already satisfied: cmake in ./lib/python3.10/site-packages (from triton==2.0.0->torch) (3.27.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./lib/python3.10/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Requirement already satisfied: pillow in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (9.2.0)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Requirement already satisfied: fiftyone in ./lib/python3.10/site-packages (0.22.3)
# Requirement already satisfied: opencv-python-headless in ./lib/python3.10/site-packages (from fiftyone) (4.8.1.78)
# Requirement already satisfied: sse-starlette<1,>=0.10.3 in ./lib/python3.10/site-packages (from fiftyone) (0.10.3)
# Requirement already satisfied: Deprecated in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (1.2.13)
# Requirement already satisfied: matplotlib in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (3.5.3)
# Requirement already satisfied: beautifulsoup4 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (4.11.1)
# Requirement already satisfied: cachetools in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (5.2.0)
# Requirement already satisfied: pprintpp in ./lib/python3.10/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: retrying in ./lib/python3.10/site-packages (from fiftyone) (1.3.4)
# Requirement already satisfied: starlette>=0.24.0 in ./lib/python3.10/site-packages (from fiftyone) (0.32.0.post1)
# Requirement already satisfied: fiftyone-db~=0.4 in ./lib/python3.10/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: PyYAML in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (6.0)
# Requirement already satisfied: regex in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (2022.8.17)
# Requirement already satisfied: psutil in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (5.9.2)
# Requirement already satisfied: xmltodict in ./lib/python3.10/site-packages (from fiftyone) (0.13.0)
# Requirement already satisfied: humanize in ./lib/python3.10/site-packages (from fiftyone) (4.8.0)
# Requirement already satisfied: motor>=2.5 in ./lib/python3.10/site-packages (from fiftyone) (3.3.1)
# Requirement already satisfied: packaging in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (21.3)
# Requirement already satisfied: voxel51-eta~=0.12 in ./lib/python3.10/site-packages (from fiftyone) (0.12.0)
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (from fiftyone) (1.24.3)
# Requirement already satisfied: scikit-learn in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (1.1.2)
# Requirement already satisfied: dacite<1.8.0,>=1.6.0 in ./lib/python3.10/site-packages (from fiftyone) (1.7.0)
# Requirement already satisfied: pandas in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (1.4.4)
# Requirement already satisfied: kaleido!=0.2.1.post1 in ./lib/python3.10/site-packages (from fiftyone) (0.2.1)
# Requirement already satisfied: mongoengine==0.24.2 in ./lib/python3.10/site-packages (from fiftyone) (0.24.2)
# Requirement already satisfied: hypercorn>=0.13.2 in ./lib/python3.10/site-packages (from fiftyone) (0.15.0)
# Requirement already satisfied: sseclient-py<2,>=1.7.2 in ./lib/python3.10/site-packages (from fiftyone) (1.8.0)
# Requirement already satisfied: scikit-image in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (0.19.3)
# Requirement already satisfied: universal-analytics-python3<2,>=1.0.1 in ./lib/python3.10/site-packages (from fiftyone) (1.1.1)
# Requirement already satisfied: Jinja2>=3 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (3.1.2)
# Requirement already satisfied: strawberry-graphql==0.138.1 in ./lib/python3.10/site-packages (from fiftyone) (0.138.1)
# Requirement already satisfied: argcomplete in ./lib/python3.10/site-packages (from fiftyone) (3.1.4)
# Requirement already satisfied: tabulate in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (0.8.10)
# Requirement already satisfied: plotly>=4.14 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (5.10.0)
# Requirement already satisfied: aiofiles in ./lib/python3.10/site-packages (from fiftyone) (23.2.1)
# Requirement already satisfied: ftfy in ./lib/python3.10/site-packages (from fiftyone) (6.1.1)
# Requirement already satisfied: pytz in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (2022.2.1)
# Requirement already satisfied: Pillow>=6.2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone) (9.2.0)
# Requirement already satisfied: fiftyone-brain~=0.13.2 in ./lib/python3.10/site-packages (from fiftyone) (0.13.3)
# Requirement already satisfied: pymongo>=3.12 in ./lib/python3.10/site-packages (from fiftyone) (4.6.0)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from fiftyone) (63.2.0)
# Requirement already satisfied: boto3 in ./lib/python3.10/site-packages (from fiftyone) (1.28.79)
# Requirement already satisfied: typing_extensions<5.0.0,>=3.7.4 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (4.3.0)
# Requirement already satisfied: graphql-core<3.3.0,>=3.2.0 in ./lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (3.2.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (2.8.2)
# Requirement already satisfied: scipy>=1.2.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from fiftyone-brain~=0.13.2->fiftyone) (1.9.1)
# Requirement already satisfied: h2>=3.1.0 in ./lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: taskgroup in ./lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (0.0.0a4)
# Requirement already satisfied: wsproto>=0.14.0 in ./lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: priority in ./lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.0)
# Requirement already satisfied: h11 in ./lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (0.14.0)
# Requirement already satisfied: tomli in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from Jinja2>=3->fiftyone) (2.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from plotly>=4.14->fiftyone) (8.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./lib/python3.10/site-packages (from pymongo>=3.12->fiftyone) (2.4.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from starlette>=0.24.0->fiftyone) (3.6.1)
# Requirement already satisfied: httpx>=0.10.0 in ./lib/python3.10/site-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.25.1)
# Requirement already satisfied: tzlocal in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (4.2)
# Requirement already satisfied: six in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (1.16.0)
# Requirement already satisfied: future in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (0.18.2)
# Requirement already satisfied: py7zr in ./lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (0.20.7)
# Requirement already satisfied: requests in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (2.28.1)
# Requirement already satisfied: rarfile in ./lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (4.1)
# Requirement already satisfied: jsonlines in ./lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (4.0.0)
# Requirement already satisfied: sortedcontainers in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (2.4.0)
# Requirement already satisfied: glob2 in ./lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (0.7)
# Requirement already satisfied: urllib3 in ./lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (1.26.18)
# Requirement already satisfied: dill in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from voxel51-eta~=0.12->fiftyone) (0.3.5.1)
# Requirement already satisfied: soupsieve>1.2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from beautifulsoup4->fiftyone) (2.3.2.post1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./lib/python3.10/site-packages (from boto3->fiftyone) (1.0.1)
# Requirement already satisfied: botocore<1.32.0,>=1.31.79 in ./lib/python3.10/site-packages (from boto3->fiftyone) (1.31.79)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in ./lib/python3.10/site-packages (from boto3->fiftyone) (0.7.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from Deprecated->fiftyone) (1.14.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from ftfy->fiftyone) (0.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from matplotlib->fiftyone) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from matplotlib->fiftyone) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from matplotlib->fiftyone) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from matplotlib->fiftyone) (3.0.9)
# Requirement already satisfied: tifffile>=2019.7.26 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-image->fiftyone) (2022.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-image->fiftyone) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-image->fiftyone) (2.8.6)
# Requirement already satisfied: imageio>=2.4.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-image->fiftyone) (2.21.2)
# Requirement already satisfied: joblib>=1.0.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-learn->fiftyone) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from scikit-learn->fiftyone) (3.1.0)
# Requirement already satisfied: sniffio>=1.1 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (3.3)
# Requirement already satisfied: hyperframe<7,>=6.0 in ./lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in ./lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.0.0)
# Requirement already satisfied: certifi in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2022.6.15)
# Requirement already satisfied: httpcore in ./lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from jsonlines->voxel51-eta~=0.12->fiftyone) (22.1.0)
# Requirement already satisfied: multivolumefile>=0.2.3 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (0.2.3)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (1.0.2)
# Requirement already satisfied: pycryptodomex>=3.16.0 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (3.19.0)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (1.0.0)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (1.1.0)
# Requirement already satisfied: brotli>=1.1.0 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (1.1.0)
# Requirement already satisfied: texttable in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (1.7.0)
# Requirement already satisfied: pyzstd>=0.15.9 in ./lib/python3.10/site-packages (from py7zr->voxel51-eta~=0.12->fiftyone) (0.15.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from requests->voxel51-eta~=0.12->fiftyone) (2.1.1)
# Requirement already satisfied: exceptiongroup in ./lib/python3.10/site-packages (from taskgroup->hypercorn>=0.13.2->fiftyone) (1.1.3)
# Requirement already satisfied: pytz-deprecation-shim in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from tzlocal->voxel51-eta~=0.12->fiftyone) (0.1.0.post0)
# Requirement already satisfied: tzdata in /CSC_CONTAINER/miniconda/envs/env1/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal->voxel51-eta~=0.12->fiftyone) (2022.2)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip3.10 install --upgrade pip

# %%
PATCH_MAX_ITER = 100
WHITEBOX_MAX_ITER = 1

# %% [markdown]
# ### Load COCO images and resize

# %%
import fiftyone as fo
import fiftyone.zoo as foz


dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="validation",
    max_samples=3,
    shuffle=True,
    seed=51,
    label_types=["detections", "segmentations"],
    classes=["person", "car"],
)
try:
    dataset.rename_sample_field("detections", "ground_truth")
except AttributeError:
    pass

# You can now work with the PIL image
coco_images = []

for sample in dataset:
    # Get the file path to the image
    image_path = sample.filepath
    
    # Open the image using PIL
    pil_image = PIL.Image.open(image_path)
    
    # Add the PIL image to the list
    im=transform(pil_image).numpy()
    coco_images.append(im)
    
coco_images = np.array(coco_images)
# Out:
# Downloading split 'validation' to '/users/antilaan/fiftyone/coco-2017/validation' if necessary
# Found annotations at '/users/antilaan/fiftyone/coco-2017/raw/instances_val2017.json'
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading 'coco-2017' split 'validation'
#  100% |█████████████████████| 3/3 [200.7ms elapsed, 0s remaining, 14.9 samples/s]
# Dataset 'coco-2017-validation-3' created

# %% [markdown]
# ### Create the detector

# %% [markdown]
# https://github.com/Trusted-AI/adversarial-robustness-toolbox/blob/435d4b87c42685ea9ba40dba2eebd94df2ce7ff9/art/estimators/object_detection/pytorch_detection_transformer.py#L42 Tää sanois että nää tulee samalla tavalla ulos tuotla niinkun tässä esimerkissä:
# https://docs.voxel51.com/recipes/adding_detections.html
# Joten implementoinnin vois tehä suoraan

# %%
detector = PyTorchDetectionTransformer(channels_first=True, preprocessing=(MEAN, STD), input_shape=INPUT_SHAPE, clip_values=(0,1))
# Out:
# Using cache found in /users/antilaan/.cache/torch/hub/facebookresearch_detr_main
# /scratch/project_2008539/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /scratch/project_2008539/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### Test detector on COCO images

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
classes = dataset.default_classes
predictions_view = dataset.take(3)
print("Testing detector on COCO images")
print(f"detecting {len(coco_images)}")
results = detector.predict(coco_images)
for i in range(len(results)):

    preds = extract_predictions(results[i], 0.8) #0.8 on thresholdi jota voi vaihtaa, 0.8 on ihan hyvä tho
    im = (torch.from_numpy(coco_images)[i].numpy().transpose(1,2,0)*255).astype(np.uint8)
    c, h, w = im.shape
    print(c,h,w)

    image = PIL.Image.open(sample.filepath)
    image = func.to_tensor(image).to(device)
    
    c, h, w = image.shape
    print(c,h,w)
    
    #plot_image_with_boxes(img=im.copy(), boxes=preds[1], pred_cls=preds[0], title="Predictions on image without patch")
    detections = []

    boxes = preds[1]
    labels = preds[0]
    scores = preds[2]
    
    for label, score, box in zip(labels, scores, boxes):
            # Convert to [top-left-x, top-left-y, width, height]
            # in relative coordinates in [0, 1] x [0, 1]
            #x1, y1, x2, y2 = box
            x1, y1 = box[0]
            x2, y2 = box[1]
            print(x1, y1)
            print(x2,y2)
            rel_box = [x1 / w, y1 / h, (x2 - x1) / w, (y2 - y1) / h]
            print(rel_box)

            detections.append(
                fo.Detection(
                    label=label,
                    bounding_box=rel_box,
                    confidence=score
                )
            )

        # Save predictions to dataset
    sample["predictions"] = fo.Detections(detections=detections)
    sample.save()
    i+=1

# Tää pitäs olla kai niin, että yksi predictio on yksi looppi mutta miten???
#for i in range(len(results)):
    #preds = extract_predictions(results[i], 0.8)
    #im = (torch.from_numpy(coco_images)[i].numpy().transpose(1,2,0)*255).astype(np.uint8)
    #plot_image_with_boxes(img=im.copy(), boxes=preds[1], pred_cls=preds[0], title="Predictions on image without patch")
    #boxes = preds[1]
    #locations, sizes = make_into_fo_format(boxes)
 #   pass

predictions = []
#print(f"classes: {preds[0]}")
#print(f"score?: {preds[2]}")

#print(f"len {len(sizes)}")
#print(f"len {len(locations)}")
#print(f"detections: {detections}")
#print(f"sample: {sample}")

predictions = []
single_prediction = {}
# Out:
# Testing detector on COCO images
# detecting 3
# 292.42258 483.70367
# 311.01352 510.30832
# [97.4741923014323, 0.6046295928955078, 6.196980794270833, 0.03325580596923828]
# 290.45187 595.61755
# 307.8292 628.79346
# [96.81729125976562, 0.7445219421386718, 5.792439778645833, 0.041469879150390625]
# 239.31216 584.85986
# 253.77473 616.9072
# [79.77072143554688, 0.7310748291015625, 4.8208567301432295, 0.0400592041015625]
# 21.91446 622.0995
# 48.291992 674.7508
# [7.304819742838542, 0.7776243591308594, 8.792510986328125, 0.06581413269042968]
# 739.0851 548.5187
# 799.9551 705.8572
# [246.3616943359375, 0.6856483459472656, 20.289998372395832, 0.19667312622070313]
# 306.42508 625.06964
# 349.49677 654.15967
# [102.14169311523438, 0.7813370513916016, 14.357228597005209, 0.036362533569335935]
# 299.29602 623.2366
# 339.17648 651.14124
# [99.76534016927083, 0.7790457153320313, 13.293487548828125, 0.03488082885742187]
# 0.035987794 623.9548
# 37.256287 672.3843
# [0.011995931466420492, 0.7799434661865234, 12.406766255696615, 0.06053688049316406]
# 254.76215 589.2492
# 270.97385 620.0358
# [84.92071533203125, 0.7365615081787109, 5.403900146484375, 0.0384832763671875]
# 76.44087 618.301
# 113.569405 676.1319
# [25.48029073079427, 0.7728762817382813, 12.376177469889322, 0.07228858947753906]
# 169.4993 579.302
# 186.9032 601.77075
# [56.49976603190104, 0.7241275024414062, 5.801300048828125, 0.0280859375]
# 276.9559 593.98987
# 294.2586 626.56433
# [92.31863403320312, 0.7424873352050781, 5.767567952473958, 0.04071807861328125]
# 326.65576 618.31604
# 429.05927 662.1496
# [108.88525390625, 0.7728950500488281, 34.134501139322914, 0.05479194641113281]
# 419.46378 596.4409
# 466.01978 704.215
# [139.82125854492188, 0.7455511474609375, 15.518666585286459, 0.13471763610839843]
# 76.96644 614.5661
# 122.61999 633.1798
# [25.655479431152344, 0.7682076263427734, 15.217849731445312, 0.023267135620117188]
# 447.61905 453.27634
# 472.34546 471.1546
# [149.20634969075522, 0.5665954208374023, 8.242136637369791, 0.02234783172607422]
# 610.0026 145.72722
# 769.53345 381.8664
# [203.3342081705729, 0.1821590232849121, 53.17694091796875, 0.29517396926879885]
# 613.1385 248.03598
# 646.2068 275.62024
# [204.3794962565104, 0.3100449752807617, 11.02276611328125, 0.034480323791503904]
# 549.5144 249.79951
# 618.647 285.04898
# [183.17146809895834, 0.31224939346313474, 23.044189453125, 0.044061832427978516]
# 501.82742 253.48116
# 546.0676 282.21335
# [167.27580769856772, 0.3168514442443848, 14.746734619140625, 0.03591524124145508]
# 746.309 268.59027
# 800.1468 290.79907
# [248.7696736653646, 0.3357378387451172, 17.9459228515625, 0.027761001586914063]
# 524.3986 170.70396
# 536.1013 193.78568
# [174.7995402018229, 0.21337995529174805, 3.9008992513020835, 0.02885213851928711]
# -0.08737445 219.16888
# 62.743015 276.16006
# [-0.02912481625874837, 0.27396110534667967, 20.943463643391926, 0.07123897552490234]
# 196.76347 92.83769
# 215.79385 128.36072
# [65.58782450358073, 0.11604711532592774, 6.3434600830078125, 0.04440378189086914]
# 171.9521 251.25424
# 198.04778 274.61688
# [57.31736755371094, 0.31406780242919924, 8.698557535807291, 0.02920330047607422]
# -0.14499426 218.68867
# 62.09009 276.0933
# [-0.04833141962687174, 0.27336084365844726, 20.745028177897137, 0.0717557716369629]
# 210.74974 94.239136
# 227.2908 127.10898
# [70.24991353352864, 0.11779891967773437, 5.5136871337890625, 0.0410873031616211]
# 53.820038 44.97938
# 618.7182 766.8159
# [17.940012613932293, 0.05622422695159912, 188.29939778645834, 0.9022956848144531]
# 549.1396 251.05713
# 616.2277 285.57498
# [183.0465291341146, 0.3138214111328125, 22.362711588541668, 0.043147315979003904]
# 484.49353 33.952488
# 506.63052 79.750755
# [161.49784342447916, 0.0424406099319458, 7.378997802734375, 0.05724783420562744]
# 461.40417 252.04477
# 545.1459 283.86798
# [153.8013916015625, 0.3150559616088867, 27.913899739583332, 0.039779014587402343]
# 514.3129 167.02008
# 526.582 194.2755
# [171.4376424153646, 0.2087751007080078, 4.089680989583333, 0.034069271087646485]
# 121.95419 185.88646
# 141.46455 259.6862
# [40.651397705078125, 0.23235807418823243, 6.5034535725911455, 0.09224966049194336]
# 657.4402 311.31668
# 799.72095 676.86786
# [219.146728515625, 0.3891458511352539, 47.426920572916664, 0.4569389724731445]
# 602.5368 321.9109
# 723.21075 624.2882
# [200.8456013997396, 0.40238861083984373, 40.224650065104164, 0.3779716491699219]
# 547.35535 315.30457
# 664.0428 588.9333
# [182.4517822265625, 0.3941307067871094, 38.89581298828125, 0.3420359039306641]
# 8.405613 191.23831
# 29.667616 218.57376
# [2.8018709818522134, 0.23904788970947266, 7.087334314982097, 0.0341693115234375]
# 203.74522 340.8719
# 255.52402 510.90106
# [67.91507466634114, 0.42608985900878904, 17.259597778320312, 0.2125364685058594]
# 30.602793 192.69412
# 64.51732 235.12425
# [10.200930913289389, 0.24086765289306641, 11.304842631022135, 0.05303766250610351]
# 142.90276 177.2701
# 165.9834 264.1207
# [47.6342519124349, 0.22158761978149413, 7.6935475667317705, 0.10856325149536133]
# 275.13464 58.713364
# 375.68665 503.26547
# [91.7115478515625, 0.07339170455932617, 33.517333984375, 0.5556901550292969]
# 579.3511 729.3057
# 616.02893 789.89575
# [193.11702473958334, 0.9116321563720703, 12.2259521484375, 0.07573753356933594]
# 119.33009 186.33733
# 138.07043 259.80588
# [39.77669779459635, 0.23292165756225586, 6.2467803955078125, 0.09183568954467773]
# 382.42508 341.39447
# 442.49777 458.60934
# [127.4750264485677, 0.4267430877685547, 20.02423095703125, 0.14651859283447266]

# %% [markdown]
# from torchvision.transforms import functional as func
# predictions_view = dataset.take(50, seed=51)
# i=0
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# classes = dataset.default_classes
#
# with fo.ProgressBar() as pb:
#     for sample in pb(predictions_view):
#         # Load image
#         image = PIL.Image.open(sample.filepath)
#         image = func.to_tensor(image).to(device)
#         c, h, w = image.shape
#         # Perform inference
#         #results = detector.predict(coco_images[i])
#         #results = detector.predict(coco_images[i])
#
#         preds = extract_predictions(results[i], 0.8)
#         labels = preds[0]
#         scores = preds[2]
#         boxes = preds[1]
#
#         # Convert detections to FiftyOne format
#         detections = []
#         for label, score, box in zip(labels, scores, boxes):
#             # Convert to [top-left-x, top-left-y, width, height]
#             # in relative coordinates in [0, 1] x [0, 1]
#             #x1, y1, x2, y2 = box
#             x1, y1 = box[0]
#             x2, y2 = box[1]
#             rel_box = [x1 / w, y1 / h, (x2 - x1) / w, (y2 - y1) / h]
#
#             detections.append(
#                 fo.Detection(
#                     label=label,
#                     bounding_box=rel_box,
#                     confidence=score
#                 )
#             )
#
#         # Save predictions to dataset
#         sample["predictions"] = fo.Detections(detections=detections)
#         sample.save()
#     i+=1
#
# print("Finished adding predictions")

# %% [markdown]
# # Do evaluation for basic model

# %%
from fiftyone import ViewField as F
# Evaluate the predictions in the `faster_rcnn` field of our `high_conf_view`
# with respect to the objects in the `ground_truth` field
high_conf_view = predictions_view.filter_labels("predictions", F("confidence") > 0.8, only_matches=False) #lukua vaihdettu
#pitää kattoa onko "detections" oikeesti se oikea fieldi...
results = high_conf_view.evaluate_detections(
    "predictions",
    gt_field="ground_truth",
    eval_key="asd",
    method="coco",
    compute_mAP=True,
)
# original
'''results = high_conf_view.evaluate_detections(
    "faster_rcnn",
    gt_field="ground_truth",
    eval_key="eval",
    compute_mAP=True,
)'''
# Out:
# Evaluating detections...
#  100% |█████████████████████| 3/3 [92.9ms elapsed, 0s remaining, 32.3 samples/s]
# Performing IoU sweep...
#  100% |█████████████████████| 3/3 [42.9ms elapsed, 0s remaining, 70.0 samples/s]
# 'results = high_conf_view.evaluate_detections(\n    "faster_rcnn",\n    gt_field="ground_truth",\n    eval_key="eval",\n    compute_mAP=True,\n)'

# %% [markdown]
# # Show results for basic evaluation

# %%
# Get the 10 most common classes in the dataset
counts = dataset.count_values("ground_truth.detections.label")
classes_top10 = sorted(counts, key=counts.get, reverse=True)[:10]
# Print a classification report for the top-10 classes
results.print_report()

print(f"map: {results.mAP()}")
# Out:
#                precision    recall  f1-score   support
#
#           car       0.00      0.00      0.00       9.0
#         chair       0.00      0.00      0.00       9.0
#           dog       0.00      0.00      0.00       1.0
#  fire hydrant       0.00      0.00      0.00       1.0
#       handbag       0.00      0.00      0.00       1.0
#        orange       0.00      0.00      0.00       1.0
#        person       0.00      0.00      0.00       7.0
#     stop sign       0.00      0.00      0.00       0.0
# traffic light       0.00      0.00      0.00       8.0
#      umbrella       0.00      0.00      0.00       3.0
#
#     micro avg       0.00      0.00      0.00      40.0
#     macro avg       0.00      0.00      0.00      40.0
#  weighted avg       0.00      0.00      0.00      40.0
#
# map: 0.0

# %% [markdown]
# # Adversarial patch attack

# %% [markdown]
# DPATCH self done https://github.com/Trusted-AI/adversarial-robustness-toolbox/blob/435d4b87c42685ea9ba40dba2eebd94df2ce7ff9/examples/get_started_fasterrcnn.py#L30

# %%
from art.attacks.evasion import RobustDPatch
print("Starting robust dpatch")
dets = detector.predict(coco_images)
filtered_dets = [filter_boxes([t], 0.8)[0] for t in dets]

x = coco_images[:-1]
targets = [filtered_dets[-1] for i in range(len(x))]

brightness_range = [1.0, 1.0]
rotation_weights = [1,0,0,0]
sample_size = 1
crop_range=[0,0]
rotation_max=0.0
scale_min=0.5
scale_max=1
distortion_scale_max=0.0
learning_rate=1.0 
max_iter=100 #Tää on esimerkissä 5000
batch_size=1
patch_shape=(3, 80, 80)
patch_location=(300,300)

ap = RobustDPatch(
        detector,
        patch_shape=patch_shape,
        patch_location=patch_location,
        crop_range=crop_range,
        brightness_range=brightness_range,
        rotation_weights=rotation_weights,
        sample_size=sample_size,
        learning_rate=learning_rate,
        max_iter=max_iter,
        batch_size=batch_size,
    )

patch = ap.generate(x=x[[0]])

# %%
count =0
accuracy_per_image = []
for image in coco_images:
    
    patched_images = ap.apply_patch(coco_images[[count]])
    dets = detector.predict(patched_images)
    count +=1
    if count == 5:
        break

    for i in range(len(dets)):
        preds_orig = extract_predictions(dets[i], 0.8)
        plot_image_with_boxes(img=patched_images[i].transpose(1,2,0).copy(), boxes=preds_orig[1], pred_cls=preds_orig[0],
                               title="Predictions on image with patch")
        accuracy = accuracy_score(y_true, preds_orig[2])

# %%
from art.attacks.evasion import DPatch
print("Starting dpatch")
dets = detector.predict(coco_images)
filtered_dets = [filter_boxes([t], 0.8)[0] for t in dets]

x = coco_images[:-1]
targets = [filtered_dets[-1] for i in range(len(x))]

brightness_range = [1.0, 1.0]
rotation_weights = [1,0,0,0]
sample_size = 1
crop_range=[0,0]
rotation_max=0.0
scale_min=0.5
scale_max=1
distortion_scale_max=0.0
learning_rate=1.0 
max_iter=100 #Tää on esimerkissä 5000
batch_size=1
patch_shape=(3, 80, 80)
patch_location=(300,300)

ap = DPatch(
        detector,
        patch_shape=patch_shape,
        learning_rate=learning_rate,
        max_iter=max_iter,
        batch_size=batch_size,
    )

patch = ap.generate(x=x[[0]])

# %%
count =0
for image in coco_images:
    
    patched_images = ap.apply_patch(coco_images[[count]])
    dets = detector.predict(patched_images)
    count +=1
    if count == 5:
        break

    for i in range(len(dets)):
        preds_orig = extract_predictions(dets[i], 0.8)
        plot_image_with_boxes(img=patched_images[i].transpose(1,2,0).copy(), boxes=preds_orig[1], pred_cls=preds_orig[0],
                               title="Predictions on image with patch")

# %% [markdown]
# ##### Targeted attack

# %%
print("Starting patch")
dets = detector.predict(coco_images)
filtered_dets = [filter_boxes([t], 0.8)[0] for t in dets]

x = coco_images[:-1]
targets = [filtered_dets[-1] for i in range(len(x))]

rotation_max=0.0
scale_min=0.5
scale_max=1
distortion_scale_max=0.0
learning_rate=1.99 
max_iter=5000 #muokattu
batch_size=16
patch_shape=(3, 300, 300)
patch_location=(100,100) # Tämän vois tehdä niin, että paikka on random/pseudorandom
patch_type="circle"
optimizer="adam"

ap = AdversarialPatchPyTorch(estimator=detector, rotation_max=rotation_max, 
                      scale_min=scale_min, scale_max=scale_max, distortion_scale_max=distortion_scale_max,
                      learning_rate=learning_rate, max_iter=max_iter, batch_size=batch_size, patch_location=patch_location,
                      patch_shape=patch_shape, patch_type=patch_type, verbose=True, targeted=True)

patch, patch_mask = ap.generate(x=x[[0]], y=targets[:1])

plt.axis("off")
plt.imshow(((patch) * patch_mask).transpose(1,2,0))
plt.show()

# %%
# Do it for all 10 images
count =0
for image in coco_images:
    
    patched_images = ap.apply_patch(coco_images[[count]], scale=0.1)
    dets = detector.predict(patched_images)
    count +=1

    for i in range(len(dets)):
        preds_orig = extract_predictions(dets[i], 0.8)
        plot_image_with_boxes(img=patched_images[i].transpose(1,2,0).copy(), boxes=preds_orig[1], pred_cls=preds_orig[0],
                               title="Predictions on image with patch")
print("Patch done")

# %% [markdown]
# ##### Untargeted attack

# %%
dets = detector.predict(coco_images)
print("Starting untargeted path")
filtered_dets = [filter_boxes([t], 0.8)[0] for t in dets]

x = coco_images[:-1]
targets = [filtered_dets[-1] for i in range(len(x))]

rotation_max=0.0
scale_min=0.5
scale_max=1
distortion_scale_max=0.0
learning_rate=1.99
max_iter=1
batch_size=16
patch_shape=(3, 300, 300)
patch_location=(100,100)
patch_type="circle"
optimizer="adam"

ap = AdversarialPatchPyTorch(estimator=detector, rotation_max=rotation_max, 
                      scale_min=scale_min, scale_max=scale_max, distortion_scale_max=distortion_scale_max,
                      learning_rate=learning_rate, max_iter=max_iter, batch_size=batch_size, patch_location=patch_location,
                      patch_shape=patch_shape, patch_type=patch_type, verbose=True, targeted=False)

patch, patch_mask = ap.generate(x=x[[0]], y=filtered_dets[:1])

plt.axis("off")
plt.imshow(((patch) * patch_mask).transpose(1,2,0))
plt.show()

# %%
# Apply patch to 10 images
count =0
for image in coco_images:
    
    patched_images = ap.apply_patch(coco_images[[count]], scale=0.3)
    dets = detector.predict(patched_images)
    count +=1
for i in range(len(dets)):
    preds_orig = extract_predictions(dets[i], 0.8)
    plot_image_with_boxes(img=patched_images[i].transpose(1,2,0).copy(), boxes=preds_orig[1], pred_cls=preds_orig[0],
                           title="Predictions on image with patch")
    print(f'Patched prediction classes for image {i+1}:', preds_orig[0])
print("untargeted patch done")

# %% [markdown]
# ##### Untargeted attack plotting the loss components over epochs

# %% [markdown]
# ALHAALLA OLEVA KOHTA LAITETTU MARKDOWNIKSI KOSKA SE ON TURHA

# %% [markdown]
# from tqdm import tqdm
#
# dets = detector.predict(coco_images)
# y = [filter_boxes([t], 0.8)[0] for t in dets]
#
# x = coco_images[:-1]
# target = [y[-1] for i in range(len(coco_images[:-1]))]
#
# rotation_max=0.0
# scale_min=0.2
# scale_max=0.4
# distortion_scale_max=0.0
# learning_rate=1.99
# max_iter=PATCH_MAX_ITER
# batch_size=16
# patch_shape=(3, 80, 80)
# patch_location=(10,10)
# patch_type="square"
# optimizer="adam"
#
# attack = AdversarialPatchPyTorch(estimator=detector, rotation_max=rotation_max,
#                       scale_min=scale_min, scale_max=scale_max, distortion_scale_max=distortion_scale_max,
#                       learning_rate=learning_rate, max_iter=max_iter, batch_size=batch_size, patch_location=patch_location,
#                       patch_shape=patch_shape, patch_type=patch_type, verbose=False, targeted=False)
#
# loss_history = []
# for i in tqdm(range(50)):
#     patch = attack.generate(x[[0]], y[:1])
#     patched_images = attack.apply_patch(x[[3]], scale=0.4)
#
#     loss_components = detector.compute_losses(patched_images, y[:1])
#     losses = {}
#     for loss in loss_components.keys():
#         if 'loss' in loss:
#             losses[loss] = loss_components[loss].item()
#     loss_history.append(losses)
#
#     if i%20==0:
#         _y = detector.predict(patched_images)
#         preds = extract_predictions(_y[0], 0.5)
#         im = (patched_images[0].transpose(1,2,0))
#         plot_image_with_boxes(img=im.copy(), boxes=preds[1], pred_cls=preds[0], title=f"Detection [with patch, iter: {i}]")
#
# _y = detector.predict(patched_images)
# preds = extract_predictions(_y[0], 0.5)
# im = (patched_images[0].transpose(1,2,0))
# plot_image_with_boxes(img=im.copy(), boxes=preds[1], pred_cls=preds[0], title=f"Detection [with patch,iter: {i}]")

# %% [markdown]
# losses = pd.DataFrame(loss_history)
# fig, axes = plt.subplots(nrows=1,ncols=3,figsize=(12,3))
# losses.loss_ce.plot(ylabel='loss', ax = axes[0], subplots=True, color='g')
# losses.loss_bbox.plot(xlabel='epoch', ax = axes[1],subplots=True, color='royalblue')
# losses.loss_giou.plot( ax = axes[2],subplots=True, color='orange')
#
#
# axes[0].set_title('Classification Loss')
# axes[1].set_title('BBox L1 Regression Loss')
# axes[2].set_title('BBox GIoU Loss')
# fig.tight_layout()
